# %% [markdown]
# # Problem Set 2
#
# Many of the concepts needed to complete this homework are introduced in the recitation notebooks and the python tutorials.

# %%
# Import the packages and libraries you will use here
from pandas.plotting import scatter_matrix
import seaborn as sns
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np

# %%
sns.color_palette("tab10")
sns.__version__
# Out:
# '0.11.0'

# %% [markdown]
# ### 1
# This exercise relates to the College data set, which can be found in the file College.csv. It contains a number of variables for 777 different universities and colleges in the US. The variables are
# * Private : Public/private indicator
# * Apps : Number of applications received
# * Accept : Number of applicants accepted
# * Enroll : Number of new students enrolled
# * Top10perc : New students from top 10 % of high school class
# * Top25perc : New students from top 25 % of high school class
# * F.Undergrad : Number of full-time undergraduates
# * P.Undergrad : Number of part-time undergraduates
# * Outstate : Out-of-state tuition
# * Room.Board : Room and board costs
# * Books : Estimated book costs
# * Personal : Estimated personal spending
# * PhD : Percent of faculty with Ph.D.’s
# * Terminal : Percent of faculty with terminal degree
# * S.F.Ratio : Student/faculty ratio
# * perc.alumni : Percent of alumni who donate
# * Expend : Instructional expenditure per student
# * Grad.Rate : Graduation rate
# Before reading the data into python, it can be viewed in Excel or a text editor is well.

# %% [markdown]
# ### (a)
# Use the pandas read_csv() function to read the data into python. Call the loaded data df. Make sure that you have the directory set to the correct location for the data or use the absolute filepath so the program knows where to look for the file. Use `head` and `tail` to show the first 10 and last 10 observations of the data,the default is five so you will need to add an argument for the number of rows.

# %%
df = pd.read_csv(r"C:\Users\katel\Desktop\ML 484\data\College.csv")
#print(df.head(10),df.tail(10)) I think this is ugly, so Imma just print the first 10
df.head(10)
# Out:
#                      Unnamed: 0 Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
# 5             Albertson College     Yes   587     479     158         38
# 6       Albertus Magnus College     Yes   353     340     103         17
# 7                Albion College     Yes  1899    1720     489         37
# 8              Albright College     Yes  1038     839     227         30
# 9     Alderson-Broaddus College     Yes   582     498     172         21
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
# 5         62          678           41     13500        3335    500       675
# 6         45          416          230     13290        5720    500      1500
# 7         68         1594           32     13868        4826    450       850
# 8         63          973          306     15595        4400    300       500
# 9         44          799           78     10468        3380    660      1800
#
#    PhD  Terminal  S.F.Ratio  perc.alumni  Expend  Grad.Rate
# 0   70        78       18.1           12    7041         60
# 1   29        30       12.2           16   10527         56
# 2   53        66       12.9           30    8735         54
# 3   92        97        7.7           37   19016         59
# 4   76        72       11.9            2   10922         15
# 5   67        73        9.4           11    9727         55
# 6   90        93       11.5           26    8861         63
# 7   89       100       13.7           37   11487         73
# 8   79        84       11.3           23   11644         80
# 9   40        41       11.5           15    8991         52

# %%
df.dtypes
# Out:
# Unnamed: 0      object
# Private         object
# Apps             int64
# Accept           int64
# Enroll           int64
# Top10perc        int64
# Top25perc        int64
# F.Undergrad      int64
# P.Undergrad      int64
# Outstate         int64
# Room.Board       int64
# Books            int64
# Personal         int64
# PhD              int64
# Terminal         int64
# S.F.Ratio      float64
# perc.alumni      int64
# Expend           int64
# Grad.Rate        int64
# dtype: object

# %% [markdown]
# ### (b)
# Read in the data again this time calling the data college and using the parameter index_col=0 in the read_csv function. Notice the difference between the index used when the dataframe is displayed.

# %%
college = pd.read_csv(r"C:\Users\katel\Desktop\ML 484\data\College.csv", index_col=0)
college.head(10)
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
# Albertson College                Yes   587     479     158         38
# Albertus Magnus College          Yes   353     340     103         17
# Albion College                   Yes  1899    1720     489         37
# Albright College                 Yes  1038     839     227         30
# Alderson-Broaddus College        Yes   582     498     172         21
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
# Albertson College                    62          678           41     13500
# Albertus Magnus College              45          416          230     13290
# Albion College                       68         1594           32     13868
# Albright College                     63          973          306     15595
# Alderson-Broaddus College            44          799           78     10468
#
#                               Room.Board  Books  Personal  PhD  Terminal  \
# Abilene Christian University        3300    450      2200   70        78
# Adelphi University                  6450    750      1500   29        30
# Adrian College                      3750    400      1165   53        66
# Agnes Scott College                 5450    450       875   92        97
# Alaska Pacific University           4120    800      1500   76        72
# Albertson College                   3335    500       675   67        73
# Albertus Magnus College             5720    500      1500   90        93
# Albion College                      4826    450       850   89       100
# Albright College                    4400    300       500   79        84
# Alderson-Broaddus College           3380    660      1800   40        41
#
#                               S.F.Ratio  perc.alumni  Expend  Grad.Rate
# Abilene Christian University       18.1           12    7041         60
# Adelphi University                 12.2           16   10527         56
# Adrian College                     12.9           30    8735         54
# Agnes Scott College                 7.7           37   19016         59
# Alaska Pacific University          11.9            2   10922         15
# Albertson College                   9.4           11    9727         55
# Albertus Magnus College            11.5           26    8861         63
# Albion College                     13.7           37   11487         73
# Albright College                   11.3           23   11644         80
# Alderson-Broaddus College          11.5           15    8991         52

# %% [markdown]
# ### (c)
# Now we will do some prelimainary analysis and visualizations of the data that was loaded
# $\mathbf{i)}$ Use the describe method of the dataframe object that you made by reading in the data to show the summary statistics of each of the columns

# %%
college.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# min      139.000000      1.000000   2340.000000  1780.000000    96.000000
# 25%      992.000000     95.000000   7320.000000  3597.000000   470.000000
# 50%     1707.000000    353.000000   9990.000000  4200.000000   500.000000
# 75%     4005.000000    967.000000  12925.000000  5050.000000   600.000000
# max    31643.000000  21836.000000  21700.000000  8124.000000  2340.000000
#
#           Personal         PhD    Terminal   S.F.Ratio  perc.alumni  \
# count   777.000000  777.000000  777.000000  777.000000   777.000000
# mean   1340.642214   72.660232   79.702703   14.089704    22.743887
# std     677.071454   16.328155   14.722359    3.958349    12.391801
# min     250.000000    8.000000   24.000000    2.500000     0.000000
# 25%     850.000000   62.000000   71.000000   11.500000    13.000000
# 50%    1200.000000   75.000000   82.000000   13.600000    21.000000
# 75%    1700.000000   85.000000   92.000000   16.500000    31.000000
# max    6800.000000  103.000000  100.000000   39.800000    64.000000
#
#              Expend  Grad.Rate
# count    777.000000  777.00000
# mean    9660.171171   65.46332
# std     5221.768440   17.17771
# min     3186.000000   10.00000
# 25%     6751.000000   53.00000
# 50%     8377.000000   65.00000
# 75%    10830.000000   78.00000
# max    56233.000000  118.00000

# %% [markdown]
# $\mathbf{ii)}$ Use the scatter_matrix function that was imported from pandas to produce scatter plots of the pairwise combinations of 6 of the variables of your choice. Adjust the figsize argument make the displayed plots more readable and understandable.

# %%
# Create a visualization
scatter_matrix(college[['Outstate', 'PhD', 'S.F.Ratio', 'Grad.Rate', 'Top10perc', 'F.Undergrad']], figsize = (14,10))
plt.tight_layout() # this makes the output a little neater when you display plots
plt.show() # this will force the plots to show, they only show without this if they are the output of the last line in a cell

# %%
sns.pairplot(data=college[['Outstate', 'PhD', 'Room.Board', 'Grad.Rate', 'Top10perc', 'F.Undergrad', 'Private']], hue='Private') #same thing in seaborn, which automatically fits to screen size.

# %% [markdown]
# $\mathbf{iii)}$ Use seaborn's or matplotlib's boxplot function to create a boxplot of Outstate on private.
# Hint: You can either pass in the columns as objects or the names of the columns and use data=college as a parameter

# %%
sns.boxplot(
    data=college,
    x="Private", y="Outstate"
)

# %% [markdown]
# $\mathbf{iv)}$  Create a new qualitative variable in the dataframe, called Elite, by binning the Top10perc variable. We are going to divide universities into two groups based on whether or not the number of students coming from the top 10% of their high school classes exceeds 50.

# %%
college['Elite'] = np.where(college['Top10perc']>=50, 1, 0)
college.sort_values(['Top10perc'], ascending=False) #Checking that it did what I think it did.  It worked.
# Out:
#                                       Private   Apps  Accept  Enroll  \
# Massachusetts Institute of Technology     Yes   6411    2140    1078
# University of California at Berkeley       No  19873    8252    3215
# Harvey Mudd College                       Yes   1377     572     178
# Yale University                           Yes  10705    2453    1317
# Duke University                           Yes  13789    3893    1583
# ...                                       ...    ...     ...     ...
# Virginia State University                  No   2996    2440     704
# Morris College                            Yes    882     730     330
# North Adams State College                  No   1563    1005     240
# Center for Creative Studies               Yes    601     396     203
# Fayetteville State University              No   1455    1064     452
#
#                                        Top10perc  Top25perc  F.Undergrad  \
# Massachusetts Institute of Technology         96         99         4481
# University of California at Berkeley          95        100        19532
# Harvey Mudd College                           95        100          654
# Yale University                               95         99         5217
# Duke University                               90         98         6188
# ...                                          ...        ...          ...
# Virginia State University                      2         30         3006
# Morris College                                 2         13          926
# North Adams State College                      1         19         1380
# Center for Creative Studies                    1         20          525
# Fayetteville State University                  1         16         2632
#
#                                        P.Undergrad  Outstate  Room.Board  \
# Massachusetts Institute of Technology           28     20100        5975
# University of California at Berkeley          2061     11648        6246
# Harvey Mudd College                              5     17230        6690
# Yale University                                 83     19840        6510
# Duke University                                 53     18590        5950
# ...                                            ...       ...         ...
# Virginia State University                      338      5587        4845
# Morris College                                  12      4515        2550
# North Adams State College                      136      5542        4330
# Center for Creative Studies                    323     11230        6643
# Fayetteville State University                  617      6806        2550
#
#                                        Books  Personal  PhD  Terminal  \
# Massachusetts Institute of Technology    725      1600   99        99
# University of California at Berkeley     636      1933   93        97
# Harvey Mudd College                      700       900  100       100
# Yale University                          630      2115   96        96
# Duke University                          625      1162   95        96
# ...                                      ...       ...  ...       ...
# Virginia State University                500       600   61        63
# Morris College                           850      2100   53        60
# North Adams State College                500      1000   65        71
# Center for Creative Studies             2340       620    8        58
# Fayetteville State University            350       766   75        75
#
#                                        S.F.Ratio  perc.alumni  Expend  \
# Massachusetts Institute of Technology       10.1           35   33541
# University of California at Berkeley        15.8           10   13919
# Harvey Mudd College                          8.2           46   21569
# Yale University                              5.8           49   40386
# Duke University                              5.0           44   27206
# ...                                          ...          ...     ...
# Virginia State University                   16.0           11    5733
# Morris College                              18.6           34    6990
# North Adams State College                   14.2           17    6562
# Center for Creative Studies                  6.8            4   13025
# Fayetteville State University               15.1           10    6972
#
#                                        Grad.Rate  Elite
# Massachusetts Institute of Technology         94      1
# University of California at Berkeley          78      1
# Harvey Mudd College                          100      1
# Yale University                               99      1
# Duke University                               97      1
# ...                                          ...    ...
# Virginia State University                     31      0
# Morris College                                60      0
# North Adams State College                     57      0
# Center for Creative Studies                   47      0
# Fayetteville State University                 24      0
#
# [777 rows x 19 columns]

# %% [markdown]
# Get a count of how many universities are in the 'Elite' category. Now make boxplot of Outstate on Elite.

# %%
college.Elite.sum()
# Out:
# 83

# %%
sns.boxplot(data=college, x='Elite', y='Outstate')

# %% [markdown]
# $\mathbf{v)}$ Use seaborn's distplot function to produce some histograms with differing numbers of bins for a quantitative variable of your choice. You can make multiple cells or if you are familiar with python try making a grid of multiple plots to be displayed by one cell.

# %%
bin_list = [2,10, 50, 100]
sns.FacetGrid(data=bin_list)
for i in bin_list:
    sns.histplot(data = college, x='Room.Board', bins = i) #distplot is depreciated.

# %% [markdown]
# You can create a grid of histograms with the hist method of the dataframe. Choose some variables that seem interesting and create hhistograms in this way.

# %%
college.hist(figsize=(14,14))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000027111E5D4F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027111F761C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027111F9E8B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027111FC80A0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000027111FFC7C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027112026E80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027112026F70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002711205C790>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000271120BB640>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000271120E3DC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000271121AB580>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000271121D2D00>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002711220A4C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027112233C40>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027112268400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027112291B80>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000271122C7340>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000271122EEAC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000271123261C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027112342AF0>]],
#       dtype=object)

# %% [markdown]
# Using the tools that were introduced and/or other ones you find, continue exploring the data set and write a brief summary of what you find. This should involve something you do that was not a part of the previous responses.
# We are not looking for anything in particular just try to make something that shows something about the data ond its relationships in graphs or summary statistics that you haven't already created above.

# %% [markdown]
# ## Exploring the Data
# 1. To get a more solid understanding of the data we explore correlation coefficients (which give us a stronger idea of how to interpret the scatter matrices above.
# 2. We also use the Finance school's describe function which performs a t-test on all variables.
# 3. We look at specifically grad rate for out of state schools (with a .57 correlation coefficient) separated by elite and non-elite schoools.

# %%
college.corr()
# Out:
#                  Apps    Accept    Enroll  Top10perc  Top25perc  F.Undergrad  \
# Apps         1.000000  0.943451  0.846822   0.338834   0.351640     0.814491
# Accept       0.943451  1.000000  0.911637   0.192447   0.247476     0.874223
# Enroll       0.846822  0.911637  1.000000   0.181294   0.226745     0.964640
# Top10perc    0.338834  0.192447  0.181294   1.000000   0.891995     0.141289
# Top25perc    0.351640  0.247476  0.226745   0.891995   1.000000     0.199445
# F.Undergrad  0.814491  0.874223  0.964640   0.141289   0.199445     1.000000
# P.Undergrad  0.398264  0.441271  0.513069  -0.105356  -0.053577     0.570512
# Outstate     0.050159 -0.025755 -0.155477   0.562331   0.489394    -0.215742
# Room.Board   0.164939  0.090899 -0.040232   0.371480   0.331490    -0.068890
# Books        0.132559  0.113525  0.112711   0.118858   0.115527     0.115550
# Personal     0.178731  0.200989  0.280929  -0.093316  -0.080810     0.317200
# PhD          0.390697  0.355758  0.331469   0.531828   0.545862     0.318337
# Terminal     0.369491  0.337583  0.308274   0.491135   0.524749     0.300019
# S.F.Ratio    0.095633  0.176229  0.237271  -0.384875  -0.294629     0.279703
# perc.alumni -0.090226 -0.159990 -0.180794   0.455485   0.417864    -0.229462
# Expend       0.259592  0.124717  0.064169   0.660913   0.527447     0.018652
# Grad.Rate    0.146755  0.067313 -0.022341   0.494989   0.477281    -0.078773
# Elite        0.257387  0.118784  0.102320   0.764976   0.609637     0.065302
#
#              P.Undergrad  Outstate  Room.Board     Books  Personal       PhD  \
# Apps            0.398264  0.050159    0.164939  0.132559  0.178731  0.390697
# Accept          0.441271 -0.025755    0.090899  0.113525  0.200989  0.355758
# Enroll          0.513069 -0.155477   -0.040232  0.112711  0.280929  0.331469
# Top10perc      -0.105356  0.562331    0.371480  0.118858 -0.093316  0.531828
# Top25perc      -0.053577  0.489394    0.331490  0.115527 -0.080810  0.545862
# F.Undergrad     0.570512 -0.215742   -0.068890  0.115550  0.317200  0.318337
# P.Undergrad     1.000000 -0.253512   -0.061326  0.081200  0.319882  0.149114
# Outstate       -0.253512  1.000000    0.654256  0.038855 -0.299087  0.382982
# Room.Board     -0.061326  0.654256    1.000000  0.127963 -0.199428  0.329202
# Books           0.081200  0.038855    0.127963  1.000000  0.179295  0.026906
# Personal        0.319882 -0.299087   -0.199428  0.179295  1.000000 -0.010936
# PhD             0.149114  0.382982    0.329202  0.026906 -0.010936  1.000000
# Terminal        0.141904  0.407983    0.374540  0.099955 -0.030613  0.849587
# S.F.Ratio       0.232531 -0.554821   -0.362628 -0.031929  0.136345 -0.130530
# perc.alumni    -0.280792  0.566262    0.272363 -0.040208 -0.285968  0.249009
# Expend         -0.083568  0.672779    0.501739  0.112409 -0.097892  0.432762
# Grad.Rate      -0.257001  0.571290    0.424942  0.001061 -0.269344  0.305038
# Elite          -0.115452  0.414428    0.302584  0.096069 -0.084863  0.343487
#
#              Terminal  S.F.Ratio  perc.alumni    Expend  Grad.Rate     Elite
# Apps         0.369491   0.095633    -0.090226  0.259592   0.146755  0.257387
# Accept       0.337583   0.176229    -0.159990  0.124717   0.067313  0.118784
# Enroll       0.308274   0.237271    -0.180794  0.064169  -0.022341  0.102320
# Top10perc    0.491135  -0.384875     0.455485  0.660913   0.494989  0.764976
# Top25perc    0.524749  -0.294629     0.417864  0.527447   0.477281  0.609637
# F.Undergrad  0.300019   0.279703    -0.229462  0.018652  -0.078773  0.065302
# P.Undergrad  0.141904   0.232531    -0.280792 -0.083568  -0.257001 -0.115452
# Outstate     0.407983  -0.554821     0.566262  0.672779   0.571290  0.414428
# Room.Board   0.374540  -0.362628     0.272363  0.501739   0.424942  0.302584
# Books        0.099955  -0.031929    -0.040208  0.112409   0.001061  0.096069
# Personal    -0.030613   0.136345    -0.285968 -0.097892  -0.269344 -0.084863
# PhD          0.849587  -0.130530     0.249009  0.432762   0.305038  0.343487
# Terminal     1.000000  -0.160104     0.267130  0.438799   0.289527  0.337758
# S.F.Ratio   -0.160104   1.000000    -0.402929 -0.583832  -0.306710 -0.291492
# perc.alumni  0.267130  -0.402929     1.000000  0.417712   0.490898  0.316690
# Expend       0.438799  -0.583832     0.417712  1.000000   0.390343  0.556524
# Grad.Rate    0.289527  -0.306710     0.490898  0.390343   1.000000  0.351825
# Elite        0.337758  -0.291492     0.316690  0.556524   0.351825  1.000000

# %%
#! pip install finance_byu
from finance_byu import summarize
fin.summarize(college)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-232-b495b9627ce6> in <module>
#       1 #! pip install finance_byu
#       2 from finance_byu import summarize
# ----> 3 fin.summarize(college)
#
# TypeError: 'module' object is not callable

# %%
sns.scatterplot(data=college, x='Grad.Rate', y='Outstate', hue="Elite", style="Elite")

# %% [markdown]
# Explain what you did and what it means here

# %% [markdown]
# I looked at Grad rate and outstate tuition, which are highly correlated, broken down by elite and non-elite schools.  While elite schools do seem to have a higher graduation rate and slightly more expensive tuition, we see less distintion between the two than i would have expected.

# %% [markdown]
# ## Chapter 3
# $\mathbf{a)}$Load in auto.csv as a dataframe and the produce a grid of the pairwise scatterplots of the variables of the dataframe

# %%
auto=pd.read_csv(r'http://faculty.marshall.usc.edu/gareth-james/ISL/Auto.csv')
auto.shape
# Out:
# (397, 9)

# %%
auto.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# year              int64
# origin            int64
# name             object
# dtype: object

# %%
auto.head(14)
# Out:
#      mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0   18.0          8         307.0        130    3504          12.0    70
# 1   15.0          8         350.0        165    3693          11.5    70
# 2   18.0          8         318.0        150    3436          11.0    70
# 3   16.0          8         304.0        150    3433          12.0    70
# 4   17.0          8         302.0        140    3449          10.5    70
# 5   15.0          8         429.0        198    4341          10.0    70
# 6   14.0          8         454.0        220    4354           9.0    70
# 7   14.0          8         440.0        215    4312           8.5    70
# 8   14.0          8         455.0        225    4425          10.0    70
# 9   15.0          8         390.0        190    3850           8.5    70
# 10  15.0          8         383.0        170    3563          10.0    70
# 11  14.0          8         340.0        160    3609           8.0    70
# 12  15.0          8         400.0        150    3761           9.5    70
# 13  14.0          8         455.0        225    3086          10.0    70
#
#     origin                       name
# 0        1  chevrolet chevelle malibu
# 1        1          buick skylark 320
# 2        1         plymouth satellite
# 3        1              amc rebel sst
# 4        1                ford torino
# 5        1           ford galaxie 500
# 6        1           chevrolet impala
# 7        1          plymouth fury iii
# 8        1           pontiac catalina
# 9        1         amc ambassador dpl
# 10       1        dodge challenger se
# 11       1         plymouth 'cuda 340
# 12       1      chevrolet monte carlo
# 13       1    buick estate wagon (sw)

# %%
auto[auto['horsepower'].str.contains('[^0-9]', regex=True)]
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 32   25.0          4          98.0          ?    2046          19.0    71
# 126  21.0          6         200.0          ?    2875          17.0    74
# 330  40.9          4          85.0          ?    1835          17.3    80
# 336  23.6          4         140.0          ?    2905          14.3    80
# 354  34.5          4         100.0          ?    2320          15.8    81
#
#      origin                  name
# 32        1            ford pinto
# 126       1         ford maverick
# 330       2  renault lecar deluxe
# 336       1    ford mustang cobra
# 354       2           renault 18i

# %%
auto['horsepower'] = auto['horsepower'].replace('?', np.NaN)

# %%
auto['horsepower'] = auto.horsepower.astype('float64')

# %%
auto['horsepower'] = auto['horsepower'].replace(np.NaN, auto.horsepower.mean()) #impute Horsepower missing values.

# %% [markdown]
# $\mathbf{b)}$ Show the correlation matrix. There are several ways to do this but you should be able to find a function that makes it for the numeric variables of a dataframe.

# %%
auto.corr()
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.776260     -0.804443   -0.771441 -0.831739
# cylinders    -0.776260   1.000000      0.950920    0.839715  0.897017
# displacement -0.804443   0.950920      1.000000    0.893833  0.933104
# horsepower   -0.771441   0.839715      0.893833    1.000000  0.860581
# weight       -0.831739   0.897017      0.933104    0.860581  1.000000
# acceleration  0.422297  -0.504061     -0.544162   -0.687039 -0.419502
# year          0.581469  -0.346717     -0.369804   -0.413022 -0.307900
# origin        0.563698  -0.564972     -0.610664   -0.453962 -0.581265
#
#               acceleration      year    origin
# mpg               0.422297  0.581469  0.563698
# cylinders        -0.504061 -0.346717 -0.564972
# displacement     -0.544162 -0.369804 -0.610664
# horsepower       -0.687039 -0.413022 -0.453962
# weight           -0.419502 -0.307900 -0.581265
# acceleration      1.000000  0.282901  0.210084
# year              0.282901  1.000000  0.184314
# origin            0.210084  0.184314  1.000000

# %%
sns.pairplot(auto)

# %% [markdown]
# $\mathbf{c)}$ Use the statsmodel OLS function to perform a linear regression with mpg as the response and year as a feature (a variable in the regression). Use the summary() method to print the results.

# %%
import statsmodels.api as sm
# fill in the variable names you plan on using in the regression
X = auto.loc[:,['weight','acceleration','year']]
y = auto['mpg']
reg_obj = sm.OLS(y,X)
results = reg_obj.fit()
print(results.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                    mpg   R-squared (uncentered):                   0.980
# Model:                            OLS   Adj. R-squared (uncentered):              0.980
# Method:                 Least Squares   F-statistic:                              6543.
# Date:                Tue, 29 Sep 2020   Prob (F-statistic):                        0.00
# Time:                        07:21:40   Log-Likelihood:                         -1057.9
# No. Observations:                 397   AIC:                                      2122.
# Df Residuals:                     394   BIC:                                      2134.
# Df Model:                           3
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# weight          -0.0070      0.000    -33.964      0.000      -0.007      -0.007
# acceleration     0.0208      0.070      0.296      0.768      -0.118       0.159
# year             0.5787      0.019     30.814      0.000       0.542       0.616
# ==============================================================================
# Omnibus:                       51.640   Durbin-Watson:                   1.189
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               91.019
# Skew:                           0.769   Prob(JB):                     1.72e-20
# Kurtosis:                       4.771   Cond. No.                     1.28e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.28e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# Do a linear regression with mpg as the outcome and all other variables except name as the predictors. Comment on the output. For instance:
# i. Is there a relationship between the predictors and the response?
# ii. Which predictors appear to have a statistically significant relationship to the response?
# iii. What does the coefficient for the year variable suggest?

# %%
auto = auto.set_index('name')
X = auto.loc[:,~auto.columns.isin(['name', 'mpg'])]
y = auto['mpg']
reg_obj = sm.OLS(y,X)
results = reg_obj.fit()
print(results.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                    mpg   R-squared (uncentered):                   0.982
# Model:                            OLS   Adj. R-squared (uncentered):              0.981
# Method:                 Least Squares   F-statistic:                              2956.
# Date:                Tue, 29 Sep 2020   Prob (F-statistic):                        0.00
# Time:                        07:21:40   Log-Likelihood:                         -1045.7
# No. Observations:                 397   AIC:                                      2105.
# Df Residuals:                     390   BIC:                                      2133.
# Df Model:                           7
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# cylinders       -0.6739      0.324     -2.081      0.038      -1.310      -0.037
# displacement     0.0208      0.008      2.732      0.007       0.006       0.036
# horsepower      -0.0328      0.012     -2.701      0.007      -0.057      -0.009
# weight          -0.0063      0.001     -9.767      0.000      -0.008      -0.005
# acceleration    -0.0535      0.089     -0.602      0.547      -0.228       0.121
# year             0.5808      0.024     24.129      0.000       0.533       0.628
# origin           1.2595      0.279      4.521      0.000       0.712       1.807
# ==============================================================================
# Omnibus:                       46.366   Durbin-Watson:                   1.263
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               86.658
# Skew:                           0.679   Prob(JB):                     1.52e-19
# Kurtosis:                       4.843   Cond. No.                     5.99e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.99e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# 1. Is there a relationship between the predictors and the response?
#     - MPG is strongly correlated with several factors in the above regression.  MPG is negatively correlated with cylinders, displacement, horesepower, and weight.  The regression above indicates additional explanatory power over cylinters that each variable presents, so the sign on the coefficient does change.  Year and origin are both positively correlated with the response.
# 2. Which predictors appear to have a statistically significant relationship to the response?
#     - With an alpha = 0.05 most predictors (all except acceleration) seem to have a statistically significant relationship to the response.  We reject the non-correlation null hypothesis for all of these predictors, except acceleration.  Likely all explanatory power of acceleration is covered in the other negatively correlated features that we see above.
# 3. What does the coefficient for the year variable suggest?
#     - The model struggles with multicollinearity (as suggested in the warnings) and should be interpretted lightly because of that.  However, year data is likely more independent than, for example, cylinder and weight data so we interpret it more liberally.  Year has a coefficient of 0.5808 suggesting that each additional year lead to a 0.5808 increase in miles per gallon efficiency.  This suggests that cars are getting more fuel efficient over time.

# %% [markdown]
# $\mathbf{d)}$ Use statsmodels' inluence_plot() function to produce diagnostic plots of the linear regression fit. Comment on any problems you see with the fit. Do the residual plots suggest any unusually large outliers? Does the leverage plot identify any observations with unusually high leverage?

# %%
sns.set(font_scale=.75)
sm.graphics.influence_plot(results)
plt.show()

# %% [markdown]
# **1.** The leverage plot (above) indicates that the Buick Estate Wagon exerts surprisingly high influence on the regression with high negative residuals, a leverate of over 0.175 and a large area.

# %% [markdown]
# $\mathbf{e)}$ Create some polynomial and interaction features from the existing set of variables and fit linear regression models with them. Do any interaction terms appear to be statistically significant? What about polynomial terms?
# A relativley easy way to do this si the use scikit-learn's polynomial features but you can add in interaction and squared columns individually to the dataframe by multiplying columns together.

# %%
auto['wd'] = auto['weight']*auto['displacement']
auto['a2'] = auto['acceleration']**2

# %%
X = auto.loc[:,~auto.columns.isin(['name', 'mpg'])]
y = auto['mpg']
reg_obj = sm.OLS(y,X)
results = reg_obj.fit()
print(results.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                    mpg   R-squared (uncentered):                   0.987
# Model:                            OLS   Adj. R-squared (uncentered):              0.986
# Method:                 Least Squares   F-statistic:                              3153.
# Date:                Tue, 29 Sep 2020   Prob (F-statistic):                        0.00
# Time:                        07:34:49   Log-Likelihood:                         -983.01
# No. Observations:                 397   AIC:                                      1984.
# Df Residuals:                     388   BIC:                                      2020.
# Df Model:                           9
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# cylinders        0.2905      0.289      1.005      0.316      -0.278       0.859
# displacement    -0.0716      0.011     -6.749      0.000      -0.092      -0.051
# horsepower      -0.0290      0.011     -2.748      0.006      -0.050      -0.008
# weight          -0.0102      0.001    -14.395      0.000      -0.012      -0.009
# acceleration    -1.3525      0.349     -3.876      0.000      -2.039      -0.666
# year             0.8446      0.036     23.562      0.000       0.774       0.915
# origin           0.5550      0.250      2.216      0.027       0.063       1.047
# wd             2.16e-05   2.19e-06      9.843      0.000    1.73e-05    2.59e-05
# a2               0.0435      0.011      4.081      0.000       0.023       0.065
# ==============================================================================
# Omnibus:                       30.738   Durbin-Watson:                   1.430
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               64.025
# Skew:                           0.430   Prob(JB):                     1.25e-14
# Kurtosis:                       4.770   Cond. No.                     2.06e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.06e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# `**1.** Both new variables are statistically significant even in the long model.  Unsurprisingly the coefficient on weight*displacement is very small, but it is still statistically signficant. While the coefficient on acceleration squared alters acceleration to have a large, negative impact and a statistically significant role in the model.

# %% [markdown]
# ## PCA
# In the first cell I have some code which will generate some random data with 500 features and 10000 observations. There will be 3 clusters of groups indicated by the y variable. Use PCA to reduce the dimensionality down to 2 principle components. Sklearn has a PCA and TruncatedSVD object you can use, the difference will just be demeaning the values or not so there shouldn't be a big difference in results from either method.

# %%
from sklearn.datasets import make_blobs
from sklearn.decomposition import PCA

SEED = 123
X, y = make_blobs(n_samples=10000, n_features=500, cluster_std=90., random_state=SEED) #adjusted the code to match the prompt

# %%
#Since standard scalar is referenced below, I took it out of my prior analysis.
"""#Standardize PCA variable scales (shouldn't be a problem given Rnorm distribution, but it's a good practice regardless)
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X)
X_scaled = scaler.transform(X)"""
# Out:
# "#Standardize PCA variable scales (shouldn't be a problem given Rnorm distribution, but it's a good practice regardless)\nfrom sklearn.preprocessing import StandardScaler\nscaler = StandardScaler()\nscaler.fit(X)\nX_scaled = scaler.transform(X)"

# %%
#Reduce dimensionality down to two components.
pca = PCA(n_components=2)
pca.fit(X_scaled)
x_pca = pca.transform(X_scaled)

# %%
x_pca.shape
# Out:
# (10000, 2)

# %% [markdown]
# Generate a plot of the 2 principal components that were found. You may find it helpful to combine X and y into a pandas DataFrame object so that it plays mroe nicely with seaborn.

# %%
pca_df= pd.DataFrame(x_pca,y) #y is index
pca_df=pca_df.reset_index()
pca_df=pca_df.rename(columns={"index": "y", 0: "x_1", 1:'x_2'})

# %%
pca_df.head()
# Out:
#    y       x_1       x_2
# 0  0 -0.354449 -0.459374
# 1  0 -0.721976 -1.074218
# 2  0 -1.493468 -1.793982
# 3  0 -0.902662 -0.963200
# 4  1  0.367523  1.387905

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(data=pca_df, x="x_1", y="x_2", hue="y", style="y")
plt.xlabel("First Principal Component")
plt.ylabel("Second Principal Component")
sns.set_palette("crest")

# %% [markdown]
# ## KMeans

# %% [markdown]
# Perform K-means clustering of the observations with K = 3. How well do the clusters that you obtained in K-means clustering compare to the true class labels? You can use the classifcation report function from sklearn to get some metrics that measure the quality of the model you used.

# %%
from sklearn.cluster import KMeans

# build the clustering model
kmeans = KMeans(n_clusters=3)
kmeans.fit(X)
kmeans.labels_
# Out:
# array([1, 1, 1, ..., 1, 0, 0])

# %%
from sklearn.metrics import classification_report
target_names = ['class 0', 'class 1', 'class 2']
print(classification_report(y, kmeans.labels_, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#      class 0       0.19      0.19      0.19      3334
#      class 1       0.14      0.14      0.14      3333
#      class 2       0.73      0.73      0.73      3333
#
#     accuracy                           0.35     10000
#    macro avg       0.35      0.35      0.35     10000
# weighted avg       0.35      0.35      0.35     10000

# %% [markdown]
# **1.** The classifications seem ot perform okay with both precision and recall, with most of the accuracy attributable to class 2 and only a small fraction of accuracy on classes 0 and 1.  Interestingly precision and recall are perfectly the same.

# %% [markdown]
# Perform K-means clustering with K = 2. Describe your results.

# %%
kmeans = KMeans(n_clusters=2)
kmeans.fit(X)
kmeans.labels_
# Out:
# array([0, 0, 0, ..., 0, 1, 0])

# %%
target_names = ['class 0', 'class 1', 'class 2']
print(classification_report(y, kmeans.labels_, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#      class 0       0.54      0.85      0.66      3334
#      class 1       0.31      0.45      0.37      3333
#      class 2       0.00      0.00      0.00      3333
#
#     accuracy                           0.43     10000
#    macro avg       0.28      0.43      0.34     10000
# weighted avg       0.28      0.43      0.34     10000
# C:\Users\katel\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# **2.** This results is much stronger recall for both class 0 and class 1 (indicating that the accuracy for these classes is high) however, we are completely unsuccessful at addressing class 2.  That said, the overall accuracy of the model actually increased from 0.35 to 0.43.

# %% [markdown]
# Now perform K-means clustering with K = 4, and describe your results.

# %%
kmeans = KMeans(n_clusters=4)
kmeans.fit(X)
kmeans.labels_
# Out:
# array([0, 3, 0, ..., 3, 2, 3])

# %%
target_names = ['class 0', 'class 1', 'class 2', 'class 3']
print(classification_report(y, kmeans.labels_, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#      class 0       0.64      0.44      0.52      3334
#      class 1       0.14      0.12      0.13      3333
#      class 2       0.18      0.13      0.15      3333
#      class 3       0.00      0.00      0.00         0
#
#     accuracy                           0.23     10000
#    macro avg       0.24      0.17      0.20     10000
# weighted avg       0.32      0.23      0.27     10000
# C:\Users\katel\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# **3.** The accuracy of this model decreased with the misallocation of some variables to a fourth class.  All methods for investigating model accuracy are down across the board.

# %% [markdown]
# Now perform K-means clustering with K = 3 on the first two principal component score vectors, rather than on the raw data. That is, perform K-means clustering on the 60 × 2 matrix of which the first column is the first principal component score vector, and the second column is the second principal component score vector. Comment on the results.

# %%
kmeans = KMeans(n_clusters=3)
kmeans.fit(pca_df[['x_1', 'x_2']])
kmeans.labels_
# Out:
# array([2, 2, 2, ..., 2, 0, 1])

# %%
target_names = ['class 0', 'class 1', 'class 2']
print(classification_report(y, kmeans.labels_, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#      class 0       0.11      0.11      0.11      3334
#      class 1       0.69      0.67      0.68      3333
#      class 2       0.13      0.13      0.13      3333
#
#     accuracy                           0.30     10000
#    macro avg       0.31      0.30      0.30     10000
# weighted avg       0.31      0.30      0.30     10000

# %% [markdown]
# **4.** This model does not perform better than a simple k means model. Accuracy is down (from 0.35 to 0.30) wihtout signifciant gains in precision or recall.  In fact, we saw losses across the board.  This does, interestingly, shift predictive power to class 1, which may indicate some additional information conveyed by the principal component analysis, expanding to include a few more components may improve the model.

# %% [markdown]
# Using of of sklearn's data scalers, perform K-means clustering with K = 3 on the data after scaling each variable to have standard deviation one. How do these results compare to those obtained in (b)? Explain.

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler() #standard scalar sets SD to 1 and mean to 0.
scaler.fit(X)
X_scaled = scaler.transform(X)

kmeans = KMeans(n_clusters=3)
kmeans.fit(X_scaled)
kmeans.labels_
# Out:
# array([0, 0, 0, ..., 0, 2, 2])

# %%
target_names = ['class 0', 'class 1', 'class 2']
print(classification_report(y, kmeans.labels_, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#      class 0       0.70      0.72      0.71      3334
#      class 1       0.16      0.15      0.15      3333
#      class 2       0.13      0.13      0.13      3333
#
#     accuracy                           0.33     10000
#    macro avg       0.33      0.33      0.33     10000
# weighted avg       0.33      0.33      0.33     10000

# %% [markdown]
# **5.** Standard scalar also doesn't significantly improve the accuracy of the model. Again, the class with the most accurate assignments shifts to class 0, but accuracy changes from 0.35 to 0.33.  Not a good look for scaling.

# %% [markdown]
# ## Supervised Machine Learning
# In this problem, you will develop a model to predict whether a given car gets high or low gas mileage based on the `Auto` data set. you should be able to use the same dataframe for the previous problem using the auto dataset here as well or you can load it in and start over if you want to practice

# %% [markdown]
# Calling the functions is similar for all of the functions from sklearn. This is one of the really nice things about the library: if you know how to use one then you know how to use them all. You will be asked to use models we have not deeply discussed in lecture but that will not change the coding aspect of it so you should be able to complete the assignment without knowing what exactly is happening. This is just meant to introduce you to how to use models from scikit-learn so don't worry if this is the case. This is one of the problems with the way a lot of people try to use machine learning so I do not recommend it in the future as predictions from a model you don't understand are probably not very good predictions no matter how good the scoring metrics do.

# %%
# this creates a variable named mpg01 that indicates whetehr or not gas mileage iss above the median of the sample
auto['mpg01'] = auto['mpg'] > auto['mpg'].median()

# %% [markdown]
# Scikit-learn is set up so that if you know how to use one model you know how to use them all. Here is an example of the steps that you will follow in general for classification, like in the following question. A regression problem is with a continuous outcome and classification is with a discrete outcome.
# ```python
# from sklearn.submoodule import Model # import a model from the appropriate submodule of scikit-learn
# model_obj = Model() # create a model object with relevant tuning parameters
# model_obj.fit(X, y) # fit the model to your data
# model_obj.score(X, y) # get a score of how well the model does using a loss function
# ```

# %% [markdown]
# $(a)$ Create an X matrix and a Y vector. The variable you created called `mpg01` will be the y variable.
# Are there any variables that should not be included? Hint: I am aking this because there is a variable that should not be included.

# %%
y=auto['mpg01']
X = auto.loc[:,~auto.columns.isin(['name', 'mpg', 'mpg01'])]

# %% [markdown]
# $(b)$ Perform Linear Discriminant Analysis (LDA) on the training data in order to predict `mpg01`. How accurate is the model?

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

lda = LinearDiscriminantAnalysis()
lda.fit(X,y)
lda.score(X,y)
# Out:
# 0.924433249370277

# %% [markdown]
# - This model correctly predicts mpg01 with 92% accuracy.

# %% [markdown]
# $(c)$ Perform Quadratic Discriminant Analysis (QDA) on the training data in order to predict `mpg01`. How accurate is the model?

# %%
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

qda = QuadraticDiscriminantAnalysis()
qda.fit(X,y)
qda.score(X,y)
# Out:
# 0.9093198992443325

# %% [markdown]
# - This model correctly predicts mpg01 with 91% accuracy.

# %% [markdown]
# $(d)$ Perform logistic regression on the training data in order to predict `mpg01`. How accurate is the model?

# %%
from sklearn.linear_model import LogisticRegression

lreg = LogisticRegression()
lreg.fit(X,y)
lreg.score(X,y)
# Out:
# C:\Users\katel\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.8866498740554156

# %% [markdown]
# - This model correctly predicts mpg01 with 89% accuracy.

# %% [markdown]
# $(e)$ Perform K-nearest Neighbors on the training data in order to predict `mpg01`. How accurate is the model?
# Which value of K seems to perform the best on this data set?

# %%
from sklearn.neighbors import KNeighborsClassifier

scores = []
for k in range(2,100):
    knn = KNeighborsClassifier(n_neighbors= k)
    knn.fit(X,y)
    score = knn.score(X,y)
    scores.append(score)

# %%
knn_df=pd.DataFrame(list(range(2,100)), scores)
knn_df=knn_df.reset_index()
knn_df=knn_df.rename(columns={"index": "score", 0: "k"})
sns.lineplot(data=knn_df, x="k", y='score')

# %% [markdown]
# - The most accurate version of this model has a 92% accuracy.  K=2 is our best predictor for this data set, however this may be a function of overfitting and the model should be tested on several different data sets to train it better.

# %% [markdown]
# $(f)$ Now run a random forest classifier on the data. If you are feeling comfortable with this, you can try different parameters to try and tune the model to give better results. This is not necessary to receive full credit.

# %%
from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier()
rfc.fit(X,y)
rfc.predict(X)
rfc.score(X,y)
# Out:
# 1.0

# %% [markdown]
# - This model returned 100% accuracy which gives me serious pause.  We should investigate and tuen for overfitting.
