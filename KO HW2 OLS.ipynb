# %%
import numpy as np
import pandas as pd
import statsmodels.formula.api as fm

# %%
df = pd.read_excel(r'C:\Users\katel\Desktop\Metrics\HW2 Stata.xlsx')

# %%
df.head()
# Out:
#          x1        x2          y
# 0 -0.370348  1.573132 -15.917490
# 1  0.436534 -1.140719 -12.589770
# 2 -0.602669 -4.533756 -20.017620
# 3 -0.522884  1.530884 -11.277970
# 4 -1.196669 -3.466375  -8.096156

# %%
df.corr()
# Out:
#           x1        x2         y
# x1  1.000000  0.307154  0.298439
# x2  0.307154  1.000000  0.790590
# y   0.298439  0.790590  1.000000

# %%
df.plot.scatter('x1', 'y')

# %%
reg = fm.ols(formula="df['y'] ~ df['x1']", data=df).fit()

# %%
print(reg.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                df['y']   R-squared:                       0.089
# Model:                            OLS   Adj. R-squared:                  0.088
# Method:                 Least Squares   F-statistic:                     97.58
# Date:                Mon, 21 Sep 2020   Prob (F-statistic):           5.09e-22
# Time:                        08:58:21   Log-Likelihood:                -4176.2
# No. Observations:                1000   AIC:                             8356.
# Df Residuals:                     998   BIC:                             8366.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.3779      0.499     -0.757      0.449      -1.357       0.601
# ...

# %%
reg2 = fm.ols(formula="df['y'] ~ df['x1'] + df['x2']", data=df).fit()

# %%
print(reg2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                df['y']   R-squared:                       0.628
# Model:                            OLS   Adj. R-squared:                  0.628
# Method:                 Least Squares   F-statistic:                     843.2
# Date:                Mon, 21 Sep 2020   Prob (F-statistic):          4.53e-215
# Time:                        08:58:21   Log-Likelihood:                -3727.8
# No. Observations:                1000   AIC:                             7462.
# Df Residuals:                     997   BIC:                             7476.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.5337      0.319     -1.674      0.095      -1.159       0.092
# ...

# %%
1.0086 - 4.9022
# Out:
# -3.8935999999999997

# %%
1.01 + 3.996 *(.975)
# Out:
# 4.9061

# %%
reg2 = fm.ols(formula="df['x1'] ~ df['x2']", data=df).fit()

# %%
print(reg2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               df['x1']   R-squared:                       0.094
# Model:                            OLS   Adj. R-squared:                  0.093
# Method:                 Least Squares   F-statistic:                     104.0
# Date:                Mon, 21 Sep 2020   Prob (F-statistic):           2.73e-23
# Time:                        09:00:20   Log-Likelihood:                -1374.5
# No. Observations:                1000   AIC:                             2753.
# Df Residuals:                     998   BIC:                             2763.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.0297      0.030     -0.979      0.328      -0.089       0.030
# ...

# %%
(-0.0297+0.0968)
# Out:
# 0.06709999999999999

# %%
1.0086+(0.968*3.9965)
# Out:
# 4.877212

# %%
(0.0968*3.9965)
# Out:
# 0.3868612
